# %% [markdown]
# ## Review (2)
#
# Thank you for the fast and good update. Most issues were fixed correctly. Please just have a look at first hypothesis testing and correct it. After then I'll accept your project.
#
# ---

# %% [markdown]
# ## Review
#
# Hi Pablo. This is Soslan. I reviewed your first project. As always I've added all my comments to new cells with different coloring.
#
# <div class="alert alert-success" role="alert">
#   If you did something great I'm using green color for my comment
# </div>
#
# <div class="alert alert-warning" role="alert">
# If I want to give you advice or think that something can be improved, then I'll use yellow. This is an optional recommendation.
# </div>
#
# <div class="alert alert-danger" role="alert">
#   If the topic requires some extra work so I can accept it then the color will be red
# </div>
#
# You did good work. Most of the tasks were done correctly, but some fixes needed. I left answers to your questions in appropriate places. I hope that my hints will help you to finish your project.
#
# Also as advice - you are using for your conclusions headers formatting. This isn't a good practice. Here a useful small tutorial to improve the formatting of your text: https://www.markdowntutorial.com/
#
# ---

# %% [markdown]
# # Sorry for being so late with this project and i assure that I have done all with me to get the best result. Thanks

# %% [markdown]
# ## <r> I've got problems when i'm converting an object type to an integer
# ## I'm not able to deal with the missing values on the hypothesis part and i get stuck on it

# %% [markdown]
# ##  Step 1. Open the data file and study the general information

# %%
import pandas as pd
df= pd.read_csv('/datasets/games.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success" role="alert">Good start. Data was opened correctly.</div>

# %% [markdown]
# ##  Step 2. Prepare the data

# %% [markdown]
# ### Replace the column names

# %%
df.columns=  df.columns.str.lower()
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Good, but you can do it even without iteration. Have a look:</div>
#
# ``df.columns = df.columns.str.lower()``

# %% [markdown]
# ### Convert the data to the required types

# %%
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df['year_of_release']= df['year_of_release'].fillna(0).astype('int')
df['year_of_release']
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16710    2016
# 16711    2006
# 16712    2016
# 16713    2003
# 16714    2016
# Name: year_of_release, Length: 16715, dtype: int64

# %%
import numpy as np
df['user_score']= df['user_score'].replace('tbd', np.nan)
df['user_score']= df['user_score'].astype('float')

# %%
df['name']
# Out:
# 0                           Wii Sports
# 1                    Super Mario Bros.
# 2                       Mario Kart Wii
# 3                    Wii Sports Resort
# 4             Pokemon Red/Pokemon Blue
#                      ...
# 16710    Samurai Warriors: Sanada Maru
# 16711                 LMA Manager 2007
# 16712          Haitaka no Psychedelica
# 16713                 Spirits & Spells
# 16714              Winning Post 8 2016
# Name: name, Length: 16715, dtype: object

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## The 'years_of_release' needs to be converted to a integer type as a appropiate data. In column'critic_score' occurs that there is no reason to maintain as a float type because it consumes a lot of memory space. The 'user_score' has include a tbd term isnside teh dataset. In this case I replace it as NaN values because it is unknown data.

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Seems reasonable.</div>

# %% [markdown]
# ### Dealing with missing values

# %%
df.isna().mean()
# Out:
# name               0.000120
# platform           0.000000
# year_of_release    0.000000
# genre              0.000120
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# critic_score       0.513192
# user_score         0.545917
# rating             0.404786
# dtype: float64

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %%
df['name'].dropna(inplace=True)
df['genre'].dropna(inplace=True)

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <s>Some explanations about what are you doing in the next cells will be helpful as it isn't evident from code.</s></div>
#
# <div class="alert alert-success" role="alert">
# Fixed</div>

# %% [markdown]
# I will to extract from he neame games the year and replace it in cases where the column year_of-release miss data

# %%
import nltk
from nltk.stem import WordNetLemmatizer

def year_name(row):
    text=row
    year=['1980', '1981','1982','1983','1984','1985','1986','1987', '1988','1989','1990', '1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2016']
    
    word_lemma= WordNetLemmatizer()
    
    words= nltk.word_tokenize(text)
    lemma=[word_lemma.lemmatize(w, pos = 'n') for w in words]
    for i in year:
        if i in lemma:
            return(lemma[-1])

# %%
df['last_obtain']= df['name'].apply(year_name)

# %%
df[df['year_of_release']==0][['year_of_release', 'last_obtain']]
# Out:
#        year_of_release last_obtain
# 183                  0        2004
# 377                  0        2004
# 456                  0        None
# 475                  0        2006
# 609                  0        None
# ...                ...         ...
# 16373                0        2008
# 16405                0        None
# 16448                0        None
# 16458                0        None
# 16522                0        None
#
# [269 rows x 2 columns]

# %%
def year_last(row):
    year= row['year_of_release']
    last= row['last_obtain']
    if (year==0)&(last!=None):
        return last
    else:
        return year

# %%
df['year_of_release']= df[['year_of_release', 'last_obtain']].apply(year_last, axis=1)

# %%
df['year_of_release']= df['year_of_release'].replace('Soccer','2009')

# %%
import numpy as np
df['year_of_release']= df['year_of_release'].replace(0,np.nan)
df['year_of_release'].dropna(inplace=True)
df['year_of_release'] = df['year_of_release'].apply(np.int64)
df['year_of_release']
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16710    2016.0
# 16711    2006.0
# 16712    2016.0
# 16713    2003.0
# 16714    2016.0
# Name: year_of_release, Length: 16715, dtype: float64

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# I'm not sure what are you trying to do with the next line of code. You converted your feature to int before. We use apply to apply some function, and you try to apply data type.
# So here everything will work without this code.</div>
#
# ``df['year_of_release'] = df['year_of_release'].apply(np.int64)``
#
# ---

# %% [markdown]
# Now we deal with the ones which have a big number of missing values

# %%
df[['critic_score', 'user_score']].describe()
# Out:
#        critic_score   user_score
# count   8137.000000  7590.000000
# mean      68.967679     7.125046
# std       13.938165     1.500006
# min       13.000000     0.000000
# 25%       60.000000     6.400000
# 50%       71.000000     7.500000
# 75%       79.000000     8.200000
# max       98.000000     9.700000

# %%
df['rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Some cases has a percentaje lower than 1-0.5% as it happens with cases like 'name' and 'genre' columns. The reason of these missing values is due to bug errors.  i opted for replace some of the missing values of 'year_of_release' by extracting some essential information of the name of the gama (contains the year). The rest of the cases has a higher percentaje of missing values (more than 50%), so i decided to keep it. It is because problems with dump data or some information has being lost while passing it to the database.

# %% [markdown]
# ### Calculate total sales for each game

# %%
df['total_sales']= df['eu_sales']+df['na_sales']+df['jp_sales']
df['total_sales']
# Out:
# 0        74.09
# 1        39.47
# 2        32.23
# 3        29.82
# 4        30.38
#          ...
# 16710     0.01
# 16711     0.01
# 16712     0.01
# 16713     0.01
# 16714     0.01
# Name: total_sales, Length: 16715, dtype: float64

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Overall good second step.</div>

# %% [markdown]
# ## Step 3. Analyze the data

# %% [markdown]
# ### Games released in different years

# %%
df['year_of_release'].value_counts().sort_values()
# Out:
# 1980.0       9
# 1984.0      14
# 1985.0      14
# 1988.0      15
# 1987.0      16
# 1990.0      16
# 1983.0      17
# 1989.0      17
# 1986.0      21
# 1982.0      36
# 1991.0      41
# 1992.0      43
# 1981.0      46
# 1993.0      62
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1999.0     338
# 2000.0     350
# 1998.0     379
# 2001.0     482
# 2016.0     502
# 2013.0     544
# 2014.0     581
# 2015.0     606
# 2012.0     653
# 2004.0     764
# 2003.0     779
# 2002.0     830
# 2005.0     941
# 2006.0    1008
# 2011.0    1137
# 2007.0    1198
# 2010.0    1255
# 2009.0    1427
# 2008.0    1429
# Name: year_of_release, dtype: int64

# %%
df['year_of_release'].hist()

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Just as an advice, barplot will look nicer here.</div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Not every year of games released  is significant and it is remarkable the years that comes from 1995 onwards. in the rest of years were released just a few of games in comparison with the bulk of data. It is natural, because during the pass of the years have been creating more games at the same time technology was being improved

# %% [markdown]
# ### Sales varied from platform to platform

# %%
sales_platform=df.groupby(['platform','year_of_release'])['total_sales'].agg('sum').to_frame().reset_index()
sales_platform
# Out:
#     platform  year_of_release  total_sales
# 0       2600           1980.0        11.26
# 1       2600           1981.0        35.36
# 2       2600           1982.0        28.57
# 3       2600           1983.0         5.78
# 4       2600           1984.0         0.27
# ..       ...              ...          ...
# 233       XB           2008.0         0.17
# 234     XOne           2013.0        17.21
# 235     XOne           2014.0        49.26
# 236     XOne           2015.0        54.67
# 237     XOne           2016.0        23.91
#
# [238 rows x 3 columns]

# %%
sales_platform.hist('year_of_release', figsize=(15,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f592ed7d490>]],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# And here too.</div>

# %%
sales_platform.groupby('platform')['total_sales'].agg('sum').sort_values().plot(kind='pie', subplots=True, figsize=(10,7))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f592ecc5650>],
#       dtype=object)

# %% [markdown]
# We separte in two different graphs from the same variable, where one represents total sales during the years and the other one total sales among the platforms

# %%
sales_platform.groupby('platform').plot(x='year_of_release', y='total_sales', ax=ax1, legend=False)
sales_platform.groupby('platform')['total_sales'].mean().sort_values().plot(kind='barh', ax=ax2)

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Excellent. Nice charts</div>

# %% [markdown]
# Let's filter the platforms with greatest total sales

# %%
stat_plat=sales_platform.groupby('platform')['total_sales'].mean().to_frame()
quantile_8= stat_plat['total_sales'].quantile(.80)
top_plat=stat_plat.query("total_sales>@quantile_8").reset_index()
top_plat
# Out:
#   platform  total_sales
# 0       DS    67.613636
# 1       PS    68.689000
# 2      PS2    87.910833
# 3      PS3    72.431818
# 4      Wii    73.951818
# 5     X360    73.034167

# %% [markdown]
# Now we create a new column with the biggest sales ones

# %%
import numpy as np
sales_platform['filter_plat']=sales_platform['platform'].where(sales_platform['platform'].isin(top_plat['platform']), np.nan)
sales_platform['filter_plat'].dropna(inplace=True)
sales_platform['filter_plat']
# Out:
# 25       DS
# 26       DS
# 27       DS
# 28       DS
# 29       DS
#        ...
# 220    X360
# 221    X360
# 222    X360
# 223    X360
# 224    X360
# Name: filter_plat, Length: 67, dtype: object

# %% [markdown]
# Finally, we distribute by year these platform which has increasingly generate money

# %%
top_plat=sales_platform.groupby(['filter_plat', 'year_of_release'])['total_sales'].agg('sum').to_frame().reset_index()
top_plat.groupby('year_of_release')['total_sales'].mean().sort_values().plot(kind='bar', legend=True, rot=45, figsize=(10,6))

# %% [markdown]
# ### Data prognosis

# %% [markdown]
# We need a general vision of data sales during the years

# %%
year_sale=df.groupby('year_of_release')['total_sales'].agg('sum').reset_index()
fig,ax = plt.subplots()
import numpy as np
x= year_sale['year_of_release']
y= year_sale['total_sales']
y_mean= [np.mean(y)]*len(x)

mean_line = ax.plot(x,y_mean, label='Mean', linestyle='--')
data_line = ax.plot(x,y, label='Data', marker='o')
plt.legend(loc='upper right')
plt.show()

# %%
year_sale.plot(kind='area', x='year_of_release', y='total_sales')

# %% [markdown]
# We want to get an insight how was the evolution's sales from each top platform during the pass of the years

# %%
fig, ax1= plt.subplots(1, figsize=(10,8))
for plat,stat_table in sales_platform.groupby('filter_plat'):
    stat_table.plot(kind='line',x= 'year_of_release',y='total_sales', legend=True, label=plat,ax=ax1, xlim=(1980,2016))

# %%
for plat,stat_table in sales_platform.groupby('platform'):
    stat_table.plot(kind='line',x= 'year_of_release',y='total_sales', legend=True, label=plat, xlim=(1980,2016))
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1085: UserWarning: Attempting to set identical left == right == 1992.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1085: UserWarning: Attempting to set identical left == right == 1996.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(left, right)
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %% [markdown]
# We want to go further and visualize the maximum and the minimum of sales from each platform.

# %%
fig, (ax1, ax2)= plt.subplots(1,2,figsize=(18,7))
for plat,stat_table in sales_platform.groupby('platform'):
    ax1.plot(stat_table['year_of_release'].max(), stat_table['total_sales'].max(),marker='o', linestyle='', ms=15, label=plat, alpha=0.5)
#     plt.xlim(1980,2015)
    ax2.plot(stat_table['year_of_release'].min(), stat_table['total_sales'].min(),marker='.', linestyle='', ms=15, label=plat, alpha=0.7)
#     plt.xlim(1980,2015)
ax1.legend(loc="upper left", ncol=4)
ax2.legend(loc="upper left", ncol=4)
ax1.set_title('Maxium')
ax2.set_title('Minium')
# Out:
# Text(0.5, 1.0, 'Minium')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Platforms that used to be popular and now have zero sales were: 2600,DC,3DO,GB,GBA,DS,NG,n64,NES,GEN,SNES,WS,PS,PS2,SCD,SNS,XB. if we look beyond the years it will take a new platform to appear 1 year and to fade 5 years

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Great analysis. Intersting charts.</div>

# %% [markdown]
# ## Platform leading sales

# %% [markdown]
# <div class="alert alert-success" role="alert">
# This two charts I'd like to see in the beginning of the step as they are more informative then histogram.</div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <s>Here you should select data period and work only with data for that period for the rest of the project.</s></div>
#
# <div class="alert alert-warning" role="alert">
# You still work with the entire dataset.
# </div>
#
# You can apply:
#
# ``df = df.query("year_of_release>=2000")``
#
# And work with this part of dataset for the rest of the project.
#
# Citation:
#
# - Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.
#
# - Work only with the data that you've decided is relevant. Disregard the data for previous years.
#
# ---

# %% [markdown]
# I have done it previosuly down here. But thanks for the aclaration

# %% [markdown]
# I took the period that collect the years from 2000 to 2015, as a relevant proportion of data

# %%
n=sales_platform.query("year_of_release>=2000")
n['platform'].count()
# Out:
# 150

# %%
plat_sale= n.groupby('platform')['total_sales'].agg('mean').reset_index()
plat_sale.sort_values(by='total_sales').plot(kind='line', x='platform', y='total_sales')

# %%
plat_sale.sort_values(by='total_sales', ascending=False)
# Out:
#    platform  total_sales
# 9       PS2    87.910833
# 2        DS    74.373000
# 15      Wii    73.951818
# 17     X360    73.034167
# 10      PS3    72.431818
# 11      PS4    66.447500
# 0       3DS    40.756667
# 4       GBA    38.158750
# 19     XOne    36.262500
# 8        PS    33.187500
# 5        GC    27.412857
# 18       XB    27.125556
# 12      PSP    20.784167
# 16     WiiU    15.248000
# 3        GB    13.660000
# 6       N64    12.086667
# 7        PC    10.902941
# 13      PSV     7.896667
# 1        DC     1.456000
# 14       WS     0.480000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Note that the platforms which are leading sales are PS: PS2PS3PS4, X360 DS, Wii and coincide with the updated ones. Even the original version of that ones has include more sales than their new versions On the other hand, the worse platform summary sales has no much difference between them and mantain low levels.

# %% [markdown]
# ### Build a box plot for the global sales

# %%
b = df.pivot_table(index='platform',values='total_sales', aggfunc=['sum', 'quantile'])
b
# Out:
#                  sum    quantile
#          total_sales total_sales
# platform
# 2600           96.07       0.460
# 3DO             0.10       0.020
# 3DS           245.64       0.120
# DC             15.68       0.135
# DS            746.86       0.100
# GB            247.26       1.120
# GBA           310.12       0.160
# GC            193.75       0.150
# GEN            29.80       0.150
# GG              0.04       0.040
# N64           214.30       0.260
# NES           245.74       1.320
# NG              1.44       0.100
# PC            237.14       0.040
# PCFX            0.03       0.030
# PS            689.95       0.240
# PS2          1062.33       0.200
# PS3           803.97       0.250
# PS4           265.79       0.170
# PSP           252.63       0.080
# PSV            47.61       0.050
# SAT            33.52       0.120
# SCD             1.81       0.065
# SNES          196.82       0.320
# TG16            0.16       0.080
# WS              1.42       0.215
# ...

# %%
fig, ax = plt.subplots(figsize=(12,7))
ax.boxplot(b) 
ax.set_xticklabels(b.index)
# Out:
# [Text(0, 0, '2600'),
#  Text(0, 0, '3DO'),
#  Text(0, 0, '3DS'),
#  Text(0, 0, 'DC'),
#  Text(0, 0, 'DS'),
#  Text(0, 0, 'GB'),
#  Text(0, 0, 'GBA'),
#  Text(0, 0, 'GC'),
#  Text(0, 0, 'GEN'),
#  Text(0, 0, 'GG'),
#  Text(0, 0, 'N64'),
#  Text(0, 0, 'NES'),
#  Text(0, 0, 'NG'),
#  Text(0, 0, 'PC'),
#  Text(0, 0, 'PCFX'),
#  Text(0, 0, 'PS'),
#  Text(0, 0, 'PS2'),
#  Text(0, 0, 'PS3'),
#  Text(0, 0, 'PS4'),
#  Text(0, 0, 'PSP'),
#  Text(0, 0, 'PSV'),
#  Text(0, 0, 'SAT'),
#  Text(0, 0, 'SCD'),
#  Text(0, 0, 'SNES'),
#  Text(0, 0, 'TG16'),
#  Text(0, 0, 'WS'),
#  Text(0, 0, 'Wii'),
#  Text(0, 0, 'WiiU'),
#  Text(0, 0, 'X360'),
#  Text(0, 0, 'XB'),
#  Text(0, 0, 'XOne')]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## The barplot show us that many of them has several differences between the rest of platforms as becoming the most popular ones. We release that there are a few of them with similar mean levels and extension

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Nice boxplot</div>

# %% [markdown]
# ### Scatter reviews and sales

# %%
df['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %% [markdown]
# I select PS2, because it is the most popular platform and the one which we have a lot of information about

# %%
review_sale=df.query("platform=='PS2'")
review_sale.plot(kind='scatter', x='user_score', y='total_sales')
review_sale[['user_score','total_sales']].corr()
# Out:
#              user_score  total_sales
# user_score      1.00000      0.18541
# total_sales     0.18541      1.00000

# %%
review_sale.plot(kind='scatter', x='critic_score', y='total_sales')
review_sale[['critic_score','total_sales']].corr()
# Out:
#               critic_score  total_sales
# critic_score      1.000000     0.408129
# total_sales       0.408129     1.000000

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <s>You don't need to group data for these tasks. Just select data for one popular platform and examine correlation for it.</s></div>
#
# <div class="alert alert-success" role="alert">
# Fixed</div>
#
# Citation:
#
# Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.
#
# ----

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## The user review has no a big influence in the level of sales of PS2 platform, as we check at the Poisson Coefficent which is close to 0. Not occurs the same with the critic reviews, in fact it has more influence than users, but no so relevant. The reason posibly is that most of the cases are concetrated in a short range of sales and just a few escape from that.

# %% [markdown]
# ### Same games in the same platforms

# %%
df['name']
# Out:
# 0                           Wii Sports
# 1                    Super Mario Bros.
# 2                       Mario Kart Wii
# 3                    Wii Sports Resort
# 4             Pokemon Red/Pokemon Blue
#                      ...
# 16710    Samurai Warriors: Sanada Maru
# 16711                 LMA Manager 2007
# 16712          Haitaka no Psychedelica
# 16713                 Spirits & Spells
# 16714              Winning Post 8 2016
# Name: name, Length: 16715, dtype: object

# %%
game_sales= df.groupby(['name','platform'])['total_sales'].agg('sum').reset_index()
game_sales[game_sales['name']==game_sales['name'].shift()]
game_same=game_sales[game_sales['name']==game_sales['name'].shift()]
top_game=game_same.groupby('name')['total_sales'].agg('max')
top_game.plot(kind='line', rot=45)

# %% [markdown]
# ### Profitable genres

# %%
genre_profit=df.groupby('genre')['total_sales'].agg('sum').reset_index()
fig1, ax1 = plt.subplots(figsize=(10,6))
ax1.pie(genre_profit['total_sales'],shadow=True, startangle=90, autopct='%1.1f%%', labels=genre_profit['genre'])
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Most profitable genres are those games of action, sports, shooter. Otherwise adventure, strategy present worse sales results.

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Great agree.</div>

# %% [markdown]
# ## Step 4. Create a user profile for each region

# %% [markdown]
# ### The top five platforms

# %%
na_profit= df.pivot_table(index='platform', values='na_sales', aggfunc=['sum'])
jp_profit= df.pivot_table(index='platform', values='jp_sales', aggfunc=['sum'])
eu_profit= df.pivot_table(index='platform', values='eu_sales', aggfunc=['sum'])

# %%
val= na_profit.merge(jp_profit, on=['platform'], how='outer')
resume= val.merge(eu_profit, on=['platform'],how='outer')
resume.columns=['na_total_sales', 'jp_total_sales', 'eu_total_sales']
resume
# Out:
#           na_total_sales  jp_total_sales  eu_total_sales
# platform
# 2600               90.60            0.00            5.47
# 3DO                 0.00            0.10            0.00
# 3DS                83.49          100.67           61.48
# DC                  5.43            8.56            1.69
# DS                382.40          175.57          188.89
# GB                114.32           85.12           47.82
# GBA               187.54           47.33           75.25
# GC                133.46           21.58           38.71
# GEN                21.05            2.70            6.05
# GG                  0.00            0.04            0.00
# N64               139.02           34.22           41.06
# NES               125.94           98.65           21.15
# NG                  0.00            1.44            0.00
# PC                 94.53            0.17          142.44
# PCFX                0.00            0.03            0.00
# ...

# %%
top5_na=resume['na_total_sales'].sort_values( ascending=False).head(5)
top5_jp=resume['jp_total_sales'].sort_values( ascending=False).head(5)
top5_eu=resume['eu_total_sales'].sort_values( ascending=False).head(5)

# %%
top5_na
# Out:
# platform
# X360    602.47
# PS2     583.84
# Wii     496.90
# PS3     393.49
# DS      382.40
# Name: na_total_sales, dtype: float64

# %%
fig,ax = plt.subplots(figsize=(15,7))
index = np.arange(len(top5_na))
opacity= 0.9
plt.bar(index+0.0,top5_na,color = 'b', width = 0.20, label='na_total_sales',alpha=opacity, align='center')
plt.bar(index+0.30,top5_jp,color = 'm', width = 0.20, label= 'jp_total_sales',alpha=opacity, align='center')
plt.bar(index+0.60,top5_eu,color = 'r', width = 0.20, label='eu_total_sales',alpha=opacity, align='center')
plt.xticks(index+0.30,resume.index)
plt.legend()
plt.xlabel('Platforms')
plt.ylabel('USD millions')
plt.title('Market profits')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#     <s>Too much information on chart. Hard to see which plarforms are top 5 in each region.</s></div>
#
# <div class="alert alert-warning" role="alert">
# Much better now, but xticks aren't correct. You have to prepare them and distances more precisely.</div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Importan quotes of this graph: The north america market generate high level of sales. The european market are mostly present in all of platforms and the japan market barely have sales in a few platforms and the volume of profits are lower. The top five platforms match in European and North America markets, but with the Japan not happens the same.

# %% [markdown]
# ### Top five Genres

# %%
genre_profit=df.pivot_table(index='genre', values=['na_sales', 'jp_sales', 'eu_sales'], aggfunc=['sum'])
genre_profit.columns=['na_total_sales', 'jp_total_sales', 'eu_total_sales']
genre_profit
# Out:
#               na_total_sales  jp_total_sales  eu_total_sales
# genre
# Action                519.13          161.43          879.01
# Adventure              63.54           52.30          105.26
# Fighting              100.33           87.48          223.36
# Misc                  212.74          108.11          407.27
# Platform              200.35          130.83          445.50
# Puzzle                 50.01           57.31          122.87
# Racing                236.51           56.71          359.35
# Role-Playing          188.71          355.41          330.81
# Shooter               317.34           38.76          592.24
# Simulation            113.52           63.80          181.92
# Sports                376.79          135.54          684.43
# Strategy               45.17           49.66           68.55

# %%
top5_na=genre_profit['na_total_sales'].sort_values( ascending=False).head(5)
top5_jp=genre_profit['jp_total_sales'].sort_values( ascending=False).head(5)
top5_eu=genre_profit['eu_total_sales'].sort_values( ascending=False).head(5)

# %%
index = np.arange(len(top5_na))
fig, ax = plt.subplots(figsize=(9.2, 5))
plt.barh(index, top5_na, align='center', alpha=0.4,label='na_total_sales', color='#3298C7')
plt.barh(index, top5_jp, align='center', alpha=0.4,label='jp_total_sales', color='#123647')
plt.barh(index, top5_eu, align='center', alpha=0.4,label='eu_total_sales', color='#73B3D0')

plt.yticks(index, genre_profit.index)
plt.ylabel('Platform')
plt.title('USD Million')
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## This graph has similar distribution of preferences between the genres and its behaviour is very similar in different usuaries from all over the world. It is significant  that the genre action is clearly recognocible as the preference of all.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#     <s>Same here. I think it is better to build separate charts for each region with top5s</s></div>

# %% [markdown]
# ### ESRB affect on sales?

# %%
rating_sale= df.pivot_table(index='rating', values=['na_sales', 'jp_sales', 'eu_sales'], aggfunc=['sum'])
rating_sale.plot()

# %% [markdown]
# ## Affects to a large extent it is for all audiences, means that a major proportion of population who are used to play this games

# %% [markdown]
# ## Step 5. Test the following hypotheses

# %% [markdown]
# ### Average user ratings of the Xbox One and PC platforms are the same.

# %% [markdown]
# Here the null hypothesis is that usuary averages are different and the alternative hypothesis is that both are the same. we are working on independent populations

# %% [markdown]
#     Ho: xbox.mean==pc.mean
#     H1: xbox.mean!=pc.mean

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Your formulation of null and alternate hypotheses are not correct. The null hypothesis isn't the hypothesis we are testing. Null hypothesis always formulates equality. Here some useful additional reading about it:</div>
#
# https://www.investopedia.com/terms/n/null_hypothesis.asp
#
# ---

# %%
xbox= df.query("platform=='XOne'").copy()
pc=df.query("platform=='PC'").copy()

# %%
xbox['user_score'].dropna(inplace=True)
pc['user_score'].dropna(inplace=True)

# %%
from scipy import stats as st
rating_xbox= xbox['user_score'].to_list()
rating_pc= pc['user_score'].to_list()
alpha=.05
results = st.ttest_ind(
    rating_xbox,
    rating_pc,
    
)
print('p_value', results.pvalue)
if (results.pvalue<alpha):
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p_value 1.3896435533548819e-05
# We reject the null hypothesis

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Despite of the high number of missing  values and drop it, we can conclude that we reject the null value, but not so far from the 0.05 alpha in comparison with the p_value result and the means of reviews from sbox and pc are the same.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <s>You can just drop nans for both cases to avoid data skew.</s></div>
#
# <div class="alert alert-danger" role="alert">
# <s>Also please formulate explicitly null and alternate hypotheses for both cases.<s></div>
#
# <div class="alert alert-success" role="alert">
# Fixed</div>

# %% [markdown]
# ### Average user ratings for the Action and Sports genres are different.

# %% [markdown]
# The study of the hypothesis here for two independent samples of genres is that the null hypothesis establish that both ratings averages are the same and the alternative hypothesis dictates that are different.

# %% [markdown]
#     Ho: action.mean== sport.mean
#     H1: action.mean!=sport.mean

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Here you formulated hypotheses correctly. Great.</div>

# %%
action=df.query("genre=='Action'").copy()
sport= df.query("genre=='Sports'").copy()

# %%
action['user_score'].dropna(inplace=True)
sport['user_score'].dropna(inplace=True)

# %%
from scipy import stats as st
rating_action= action['user_score'].to_list()
rating_sport= sport['user_score'].to_list()
alpha=.05
results = st.ttest_ind(
    rating_action,
    rating_sport,
    
)
print('p_value', results.pvalue)
if (results.pvalue<alpha):
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p_value 0.10406951359049141
# We can't reject the null hypothesis

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Correct. But we can't claim that averages are equal. We just say that we can't reject null hypothesis :)</div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## To summing up, we cannot reject the null hypothesis, so it is evident as the high p_value shows that both rating averages are more less similar
